# %%
import pandas as pd
dname = 'occupancy'
df = pd.read_csv(f'{dname}.csv', sep=',')
print(df.shape)
df = df.select_dtypes(include=['number'])
print(df.isnull().sum())
print(df.shape)
# Out:
# (10129, 17)
# S1_Temp                 0
# S2_Temp                 0
# S3_Temp                 0
# S4_Temp                 0
# S1_Light                0
# S2_Light                0
# S3_Light                0
# S4_Light                0
# S1_Sound                0
# S2_Sound                0
# S3_Sound                0
# S4_Sound                0
# S5_CO2                  0
# S5_CO2_Slope            0
# S6_PIR                  0
# S7_PIR                  0
# Room_Occupancy_Count    0
# dtype: int64
# (10129, 17)

# %%
df.to_csv(f'{dname}.csv', sep=',', index=False)
